# %% [markdown]
# # ⭐List

# %% [markdown]
# 💡特别注意
#
#
# 在list的修改中，我们经常用到一些方法
# - mylist.append()
# - mylist.clear()
# - mylist.insert()
# - mylist.remove()
# ...
#
# 这些方法不会返回值（或者返回none）只改变`mylist`这个原列表的内容。常常单独在程序中占一行。
#
# >在这里，点前面是什么，什么指向的内存就会改变。经过list方法的修改，`mylist`作为原列表会发生变化。
#
# 如果需要在后面的程序再次使用原列表，需要进行copy。尤其需要注意的是，赋值给一个新的变量不是一种有效的copy，而只是创建了一个新的指向内存的reference。

# %% [markdown]
# ### range函数的用法

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Indexing

# %%
animals = ["dog", "cat", "bird", "fish", "horse", "cow"]

print(animals[2])

animals[4] = "sheep"
print(animals)

print(animals[-2:])

animals.append("chicken")
print(animals)

print(animals[:3])

print(animals)
# Out:
# bird
# ['dog', 'cat', 'bird', 'fish', 'sheep', 'cow']
# ['sheep', 'cow']
# ['dog', 'cat', 'bird', 'fish', 'sheep', 'cow', 'chicken']
# ['dog', 'cat', 'bird']
# ['dog', 'cat', 'bird', 'fish', 'sheep', 'cow', 'chicken']

# %%
my_dict = {1:9, 2:8}
print(type(str(value) for value in my_dict.values()))
print(str(value) for value in my_dict.values())
(a,b) = (value ** 2 for value in my_dict.values())
print(a,b)
# Out:
# <class 'generator'>
# <generator object <genexpr> at 0x0000016FDD920510>
# 81 64

# %% [markdown]
# ### list VS tuple

# %%
var1 = ("hello",)
var2 = ("hello")

print(type(var1))
print(type(var2))
# Out:
# <class 'tuple'>
# <class 'str'>

# %% [markdown]
# 可以看到当创建一个`单元素tuple`的时候，需要加一个，来表示这是一个tuple而不是普通的优先运算括号

# %% [markdown]
# ## ⭐list的增删查改

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 改

# %% [markdown]
# >list[] = "new item"
#
# 重新分配`某个index`对应的`item内容`

# %%
thislist = ["apple", "banana", "cherry", "orange", "kiwi", "mango"]
thislist[1] = "wzr"
print(thislist)
# Out:
# ['apple', 'wzr', 'cherry', 'orange', 'kiwi', 'mango']

# %% [markdown]
# >list[1:3] = "new item"
#
# 重新分配`某段index`对应的`list内容`

# %%
thislist = ["apple", "banana", "cherry", "orange", "kiwi", "mango"]
thislist[1:3] = "wzr"
print(thislist)
# Out:
# ['apple', 'w', 'z', 'r', 'orange', 'kiwi', 'mango']

# %%
thislist = ["apple", "banana", "cherry", "orange", "kiwi", "mango"]

thislist[1:3] = ["wzr"]

print(thislist)
# Out:
# ['apple', 'wzr', 'orange', 'kiwi', 'mango']

# %%
thislist = ["apple", "banana", "cherry", "orange", "kiwi", "mango"]

thislist[1:3] = ["blackcurrant", "watermelon"]

print(thislist)
# Out:
# ['apple', 'blackcurrant', 'watermelon', 'orange', 'kiwi', 'mango']

# %% [markdown]
# ## 增

# %%
thislist = ["apple", "banana", "cherry", "orange", "kiwi", "mango"]
thislist.insert(2,"wzr")    #把wzr增插到thislist第三个位置
print(thislist)
# Out:
# ['apple', 'banana', 'wzr', 'cherry', 'orange', 'kiwi', 'mango']

# %%
thislist = ["apple", "banana", "cherry", "orange", "kiwi", "mango"]
thislist.append("wzr")      #把wzr增插到thislist最后一个位置
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'orange', 'kiwi', 'mango', 'wzr']

# %%
thislist = ["apple", "banana", "cherry", "orange", "kiwi", "mango"]
me = ["ww", "zz", "rr"]
thislist.extend(me)
me.extend(thislist)
print(thislist)
print(me)
# Out:
# ['apple', 'banana', 'cherry', 'orange', 'kiwi', 'mango', 'ww', 'zz', 'rr']
# ['ww', 'zz', 'rr', 'apple', 'banana', 'cherry', 'orange', 'kiwi', 'mango', 'ww', 'zz', 'rr']

# %% [markdown]
# ## 删

# %% [markdown]
# >.remove()
#
#
# 根据item内容删除列表中的item

# %%
thislist = ["apple", "banana", "cherry", "orange", "kiwi", "mango"]
thislist.remove("apple")
print(thislist)
# Out:
# ['banana', 'cherry', 'orange', 'kiwi', 'mango']

# %% [markdown]
# list里面有多个同样名字的item的时候，remove会删除第一个遇到的item

# %%
thislist = ["apple", "apple", "apple", "orange", "kiwi", "mango"]
thislist.remove("apple")
print(thislist)
# Out:
# ['apple', 'apple', 'orange', 'kiwi', 'mango']

# %% [markdown]
# >.pop()
#
# 根据index删除列表中的内容

# %%
#remove item index
thislist = ["apple", "banana", "cherry", "orange", "kiwi", "mango"]
thislist.pop(1)
print(thislist)
# Out:
# ['apple', 'cherry', 'orange', 'kiwi', 'mango']

# %% [markdown]
# >.clear()
#
# 清空列表

# %%
thislist = ["apple", "banana", "cherry", "orange", "kiwi", "mango"]
thislist.clear()
print(thislist)
# Out:
# []

# %% [markdown]
# ##  查

# %%
#遍历item实现list打印
thislist = ["apple", "banana", "cherry", "orange", "kiwi", "mango"]
for x in thislist:
    print(x)
# Out:
# apple
# banana
# cherry
# orange
# kiwi
# mango

# %%
#遍历item index实现list打印
thislist = ["apple", "banana", "cherry", "orange", "kiwi", "mango"]
for i in range(len(thislist)):
    print(thislist[i])
# Out:
# apple
# banana
# cherry
# orange
# kiwi
# mango

# %%
#使用 while 循环打印所有项目，通过遍历所有索引编号
thislist = ["apple", "banana", "cherry", "orange", "kiwi", "mango"]
i = 0
while i < len(thislist):
    print(thislist[i])
    i = i + 1
# Out:
# apple
# banana
# cherry
# orange
# kiwi
# mango

# %% [markdown]
# 📌列表推导式（List Comprehension）是 Python 中一种简洁、易读的方式，用来创建新的列表。
# 表达式还可以包含条件，但不像筛选器那样，而是作为操纵结果的一种方式：
#
# > 示例：假设有一个水果列表，您想要一个新列表，其中仅包含名称中带有字母 “a” 的水果。

# %% [markdown]
# #语法
# newlist = [expression for item in iterable if condition == True]
# ![image.png](attachment:image.png)

# %%
#如果不使用列表推导式，不得不编写一个带有条件测试的 for 语句：

thislist = ["apple", "banana", "cherry", "orange", "kiwi", "mango"]
newlist = []

for x in thislist:
    if "a" in x:
        newlist.append(x)

print(newlist)
# Out:
# ['apple', 'banana', 'orange', 'mango']

# %%
#使用列表推导式，只需要一行代码就可以完成所有操作：

thislist = ["apple", "banana", "cherry", "orange", "kiwi", "mango"]
newlist = [i + "wzr" for i in thislist if "a" in i]
print(newlist)
# Out:
# ['applewzr', 'bananawzr', 'orangewzr', 'mangowzr']

# %%
# 也可以用来创建可迭代对象
newlist = [x**2 for x in range(5, 12)]
print(newlist)
# Out:
# [25, 36, 49, 64, 81, 100, 121]
